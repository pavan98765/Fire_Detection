# %% [markdown]
# ## predict on single image

# %%
# !yolo task=detect mode=predict model={model_path} conf={confidence_threshold} source={source_path} save={save_output}

# %%
# !yolo task=detect mode=predict model=../models/best.pt conf=0.25 source=../dataset/test/images/621_jpg.rf.6f6b36ba93a06a78068271c079fb91d0.jpg save=True
# Out:
# Ultralytics YOLOv8.0.196  Python-3.10.0 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 C:\Users\Jarvis\Desktop\Web\Fire_Detection\Code\..\dataset\test\images\621_jpg.rf.6f6b36ba93a06a78068271c079fb91d0.jpg: 800x800 1 fire - v1 2024-01-12 8-02pm, 18.9ms
# Speed: 8.1ms preprocess, 18.9ms inference, 5.7ms postprocess per image at shape (1, 3, 800, 800)
# Results saved to runs\detect\predict2
#  Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# ## Visualize the Prediction on a single image

# %%
import os
import cv2
from ultralytics import YOLO

# Initialize the YOLO model
model_path = "../models/best.pt"
model = YOLO(model_path)

# Load an image
image_path = "../dataset/test/images/new_fire_fire-538_png_jpg.rf.a0a8afd83ed3d773494b3da41d6e390b.jpg"
img = cv2.imread(image_path)

# Perform prediction
results = model.predict([img])

# Assuming 'results[0].boxes' contains the detection results for the first (and in this case, only) image
detections = results[0].boxes

# Check if any detections were made
if detections.data.shape[0] > 0:
    for i in range(detections.data.shape[0]):
        box = detections.data[i]
        x1, y1, x2, y2 = map(int, box[:4])  # Extract bounding box coordinates
        conf = box[4].item()  # Confidence score

        # Draw the bounding box
        cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 4)

        # Prepare the label as "Fire" and the confidence score
        label = f'Fire: {conf:.2f}'

        # Calculate text width & height to draw the transparent box as background of the text
        (w, h), _ = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.9, 2)

        # Display the label at the top of the bounding box
        label_position = (x1, y1 - 15 if y1 - 15 > 15 else y1 + 15)
        cv2.rectangle(img, (x1, label_position[1] - h - 3), (x1 + w, label_position[1] + h - 3), (0, 255, 0), -1)
        cv2.putText(img, label, label_position, cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 0, 0), 2)

# Display the image with detections
cv2.imshow("Detections", img)
cv2.waitKey(0)  # Wait for a key press to exit
cv2.destroyAllWindows()

# Save the result
# Extract filename and extension
filename = os.path.basename(image_path)
output_path = f"../results/{filename}"
cv2.imwrite(output_path, img)
print(f"Image saved to {output_path}")
# Out:
# 0: 800x800 2 fire - v1 2024-01-12 8-02pms, 19.0ms
# Speed: 5.0ms preprocess, 19.0ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 800)
# Image saved to ../results/new_fire_fire-538_png_jpg.rf.a0a8afd83ed3d773494b3da41d6e390b.jpg

# %% [markdown]
# ## Realtime pred on web cam

# %%
import cv2
from ultralytics import YOLO

# Initialize the YOLO model
model_path = "../models/best.pt"
model = YOLO(model_path)

# Open a connection to the webcam
cap = cv2.VideoCapture(0)

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
    if not ret:
        break

    # Perform fire detection on the current frame
    results = model.predict([frame])  # Get predictions for the current frame

    # Assuming 'results[0].boxes' contains the detection results
    detections = results[0].boxes

    # Check if any detections were made
    if detections.data.shape[0] > 0:
        for i in range(detections.data.shape[0]):
            box = detections.data[i]
            x1, y1, x2, y2 = map(int, box[:4])  # Extract bounding box coordinates
            conf = box[4].item()  # Confidence score

            # Draw the bounding box
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 4)

            # Prepare the label as "Fire" and the confidence score
            label = f'Fire: {conf:.2f}'

            # Calculate text width & height to draw the transparent box as background of the text
            (w, h), _ = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.9, 2)

            # Display the label at the top of the bounding box
            label_position = (x1, y1 - 15 if y1 - 15 > 15 else y1 + 15)
            cv2.rectangle(frame, (x1, label_position[1] - h - 3), (x1 + w, label_position[1] + h - 3), (0, 255, 0), -1)
            cv2.putText(frame, label, label_position, cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 0, 0), 2)

    # Display the resulting frame with detections
    cv2.imshow('Real-Time Fire Detection', frame)

    # Break the loop with the 'q' key
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# When everything is done, release the capture
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 608x800 (no detections), 17.1ms
# Speed: 3.0ms preprocess, 17.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 15.0ms
# Speed: 4.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 15.2ms
# Speed: 4.0ms preprocess, 15.2ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 14.9ms
# Speed: 4.0ms preprocess, 14.9ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 15.7ms
# Speed: 3.3ms preprocess, 15.7ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 16.0ms
# Speed: 3.3ms preprocess, 16.0ms inference, 1.2ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 15.1ms
# Speed: 4.0ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 15.9ms
# Speed: 3.0ms preprocess, 15.9ms inference, 0.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 15.0ms
# Speed: 3.5ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 16.0ms
# Speed: 3.5ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 15.5ms
# Speed: 3.5ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 15.6ms
# Speed: 4.0ms preprocess, 15.6ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 15.7ms
# Speed: 3.0ms preprocess, 15.7ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 14.6ms
# Speed: 3.8ms preprocess, 14.6ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 15.0ms
# Speed: 4.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 16.1ms
# Speed: 3.0ms preprocess, 16.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 15.6ms
# Speed: 3.5ms preprocess, 15.6ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 14.9ms
# Speed: 3.5ms preprocess, 14.9ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 15.8ms
# Speed: 3.0ms preprocess, 15.8ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 21.0ms
# Speed: 4.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 22.0ms
# Speed: 3.0ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 22.5ms
# Speed: 3.0ms preprocess, 22.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 22.0ms
# Speed: 3.1ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 23.2ms
# Speed: 3.1ms preprocess, 23.2ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 22.9ms
# Speed: 3.6ms preprocess, 22.9ms inference, 1.2ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 23.8ms
# Speed: 4.0ms preprocess, 23.8ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 25.1ms
# Speed: 3.5ms preprocess, 25.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 25.0ms
# Speed: 3.9ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 24.8ms
# Speed: 3.5ms preprocess, 24.8ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 24.9ms
# Speed: 4.5ms preprocess, 24.9ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 25.2ms
# Speed: 3.5ms preprocess, 25.2ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 26.9ms
# Speed: 4.0ms preprocess, 26.9ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 26.4ms
# Speed: 3.5ms preprocess, 26.4ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 26.8ms
# Speed: 5.0ms preprocess, 26.8ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 26.3ms
# Speed: 4.5ms preprocess, 26.3ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 27.3ms
# Speed: 4.1ms preprocess, 27.3ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 27.7ms
# Speed: 3.0ms preprocess, 27.7ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 28.1ms
# Speed: 4.0ms preprocess, 28.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 28.9ms
# Speed: 3.0ms preprocess, 28.9ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 29.0ms
# Speed: 3.0ms preprocess, 29.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 28.5ms
# Speed: 3.5ms preprocess, 28.5ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 29.2ms
# Speed: 3.0ms preprocess, 29.2ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 29.5ms
# Speed: 3.5ms preprocess, 29.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 31.1ms
# Speed: 2.8ms preprocess, 31.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 30.6ms
# Speed: 3.5ms preprocess, 30.6ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 29.4ms
# Speed: 4.0ms preprocess, 29.4ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 30.7ms
# Speed: 3.6ms preprocess, 30.7ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 31.2ms
# Speed: 3.5ms preprocess, 31.2ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 31.3ms
# Speed: 4.0ms preprocess, 31.3ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 31.3ms
# Speed: 3.0ms preprocess, 31.3ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 28.1ms
# Speed: 3.0ms preprocess, 28.1ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 22.6ms
# Speed: 4.0ms preprocess, 22.6ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 22.5ms
# Speed: 3.5ms preprocess, 22.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 22.6ms
# Speed: 3.6ms preprocess, 22.6ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 22.6ms
# Speed: 4.0ms preprocess, 22.6ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 17.0ms
# Speed: 4.0ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 17.2ms
# Speed: 3.0ms preprocess, 17.2ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 17.5ms
# Speed: 3.0ms preprocess, 17.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 16.5ms
# Speed: 3.5ms preprocess, 16.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 17.0ms
# Speed: 3.1ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 16.8ms
# Speed: 4.0ms preprocess, 16.8ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 16.5ms
# Speed: 3.7ms preprocess, 16.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
# 0: 608x800 (no detections), 17.4ms
# Speed: 3.0ms preprocess, 17.4ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 15.6ms
# Speed: 3.5ms preprocess, 15.6ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 15.5ms
# Speed: 3.1ms preprocess, 15.5ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 14.7ms
# Speed: 3.4ms preprocess, 14.7ms inference, 1.2ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 16.2ms
# Speed: 2.7ms preprocess, 16.2ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 15.0ms
# Speed: 3.5ms preprocess, 15.0ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 15.1ms
# Speed: 3.1ms preprocess, 15.1ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 15.9ms
# Speed: 3.5ms preprocess, 15.9ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 16.1ms
# Speed: 3.0ms preprocess, 16.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.8ms
# Speed: 4.6ms preprocess, 13.8ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.7ms
# Speed: 3.0ms preprocess, 13.7ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.8ms
# Speed: 3.5ms preprocess, 13.8ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.3ms
# Speed: 4.0ms preprocess, 13.3ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.5ms
# Speed: 3.0ms preprocess, 13.5ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.7ms
# Speed: 3.5ms preprocess, 13.7ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 14.0ms
# Speed: 3.8ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 14.5ms
# Speed: 3.1ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 14.1ms
# Speed: 3.0ms preprocess, 14.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 14.6ms
# Speed: 3.0ms preprocess, 14.6ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.5ms
# Speed: 4.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 14.1ms
# Speed: 3.6ms preprocess, 14.1ms inference, 0.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.5ms
# Speed: 3.5ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 14.1ms
# Speed: 3.0ms preprocess, 14.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 14.0ms
# Speed: 3.2ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.5ms
# Speed: 3.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.8ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.1ms
# Speed: 3.4ms preprocess, 13.1ms inference, 2.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.1ms
# Speed: 4.0ms preprocess, 13.1ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 14.0ms
# Speed: 4.3ms preprocess, 14.0ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.8ms
# Speed: 3.5ms preprocess, 12.8ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.5ms
# Speed: 3.5ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.4ms
# Speed: 4.6ms preprocess, 12.4ms inference, 1.4ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.5ms
# Speed: 3.7ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 11.8ms
# Speed: 3.8ms preprocess, 11.8ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 3.3ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.6ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.6ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.1ms
# Speed: 3.6ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.8ms
# Speed: 3.0ms preprocess, 12.8ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.1ms
# Speed: 4.5ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.1ms
# Speed: 3.3ms preprocess, 12.1ms inference, 0.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 4.0ms preprocess, 12.5ms inference, 0.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.6ms preprocess, 12.5ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.8ms
# Speed: 3.3ms preprocess, 12.8ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.1ms
# Speed: 2.5ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.5ms
# Speed: 3.0ms preprocess, 13.5ms inference, 0.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.9ms
# Speed: 3.0ms preprocess, 12.9ms inference, 0.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.4ms
# Speed: 3.5ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.0ms
# Speed: 3.5ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 4.4ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 4.0ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.1ms
# Speed: 4.0ms preprocess, 12.1ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
# 0: 608x800 (no detections), 12.4ms
# Speed: 3.5ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 4.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.6ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.8ms
# Speed: 4.0ms preprocess, 12.8ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.0ms
# Speed: 3.6ms preprocess, 12.0ms inference, 2.1ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.5ms
# Speed: 2.7ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.3ms
# Speed: 3.3ms preprocess, 13.3ms inference, 1.3ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.0ms
# Speed: 3.3ms preprocess, 12.0ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.4ms
# Speed: 3.0ms preprocess, 13.4ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.7ms
# Speed: 4.1ms preprocess, 12.7ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.6ms
# Speed: 3.6ms preprocess, 13.6ms inference, 0.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.5ms
# Speed: 2.6ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.1ms
# Speed: 3.5ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.1ms
# Speed: 2.7ms preprocess, 13.1ms inference, 1.8ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 2.7ms preprocess, 12.5ms inference, 0.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 1 fire - v1 2024-01-12 8-02pm, 13.1ms
# Speed: 3.3ms preprocess, 13.1ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 1 fire - v1 2024-01-12 8-02pm, 12.5ms
# Speed: 3.6ms preprocess, 12.5ms inference, 2.1ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.1ms
# Speed: 2.9ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.2ms
# Speed: 3.0ms preprocess, 13.2ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.4ms
# Speed: 2.8ms preprocess, 13.4ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.5ms
# Speed: 3.3ms preprocess, 13.5ms inference, 0.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.2ms
# Speed: 3.0ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 2.5ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.3ms
# Speed: 2.5ms preprocess, 13.3ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 3.2ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.1ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.0ms
# Speed: 3.5ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 4.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.6ms
# Speed: 3.0ms preprocess, 12.6ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.9ms
# Speed: 3.2ms preprocess, 12.9ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.6ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.4ms
# Speed: 3.0ms preprocess, 13.4ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 4.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.9ms
# Speed: 3.0ms preprocess, 12.9ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.1ms
# Speed: 3.1ms preprocess, 12.1ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 4.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.1ms
# Speed: 3.0ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 4.4ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.9ms
# Speed: 3.0ms preprocess, 12.9ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 4.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.4ms
# Speed: 3.5ms preprocess, 13.4ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.1ms
# Speed: 4.1ms preprocess, 12.1ms inference, 2.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.1ms
# Speed: 3.0ms preprocess, 12.1ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.6ms
# Speed: 3.9ms preprocess, 12.6ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.6ms
# Speed: 3.0ms preprocess, 12.6ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.3ms
# Speed: 3.0ms preprocess, 13.3ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 14.1ms
# Speed: 4.3ms preprocess, 14.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.0ms
# Speed: 4.0ms preprocess, 12.0ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.6ms
# Speed: 3.0ms preprocess, 12.6ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.2ms
# Speed: 4.0ms preprocess, 13.2ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.6ms
# Speed: 3.0ms preprocess, 13.6ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 11.5ms
# Speed: 3.6ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.8ms
# Speed: 3.0ms preprocess, 12.8ms inference, 0.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.2ms
# Speed: 3.5ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.8ms
# Speed: 4.5ms preprocess, 13.8ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 4.1ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.6ms
# Speed: 3.3ms preprocess, 12.6ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.2ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.2ms
# Speed: 3.1ms preprocess, 12.2ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.7ms
# Speed: 4.0ms preprocess, 12.7ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.1ms
# Speed: 4.5ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.8ms
# Speed: 4.4ms preprocess, 12.8ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.4ms
# Speed: 3.5ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.3ms
# Speed: 3.5ms preprocess, 12.3ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.1ms
# Speed: 3.0ms preprocess, 13.1ms inference, 1.2ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.1ms
# Speed: 3.5ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 11.5ms
# Speed: 3.8ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.6ms
# Speed: 3.4ms preprocess, 12.6ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.1ms
# Speed: 3.0ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.2ms
# Speed: 3.0ms preprocess, 13.2ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.6ms
# Speed: 3.0ms preprocess, 12.6ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.8ms
# Speed: 3.5ms preprocess, 12.8ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.0ms
# Speed: 4.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.5ms
# Speed: 3.5ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 11.5ms
# Speed: 4.0ms preprocess, 11.5ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.9ms
# Speed: 4.2ms preprocess, 12.9ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.9ms
# Speed: 3.0ms preprocess, 13.9ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 3.3ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.1ms
# Speed: 3.0ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.8ms
# Speed: 3.0ms preprocess, 13.8ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.6ms
# Speed: 4.0ms preprocess, 12.6ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.5ms
# Speed: 4.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.1ms
# Speed: 4.5ms preprocess, 13.1ms inference, 0.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.8ms
# Speed: 3.0ms preprocess, 12.8ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.9ms
# Speed: 3.0ms preprocess, 12.9ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.2ms
# Speed: 3.6ms preprocess, 12.2ms inference, 1.6ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.1ms
# Speed: 3.0ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.1ms
# Speed: 3.0ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.9ms
# Speed: 3.0ms preprocess, 12.9ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 4.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.8ms
# Speed: 3.8ms preprocess, 12.8ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 11.9ms
# Speed: 3.5ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 2.8ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 4.0ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.2ms
# Speed: 3.8ms preprocess, 13.2ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.2ms
# Speed: 3.3ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 4.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.6ms
# Speed: 3.0ms preprocess, 13.6ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.5ms
# Speed: 3.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.1ms
# Speed: 4.2ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.9ms
# Speed: 4.0ms preprocess, 12.9ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.8ms
# Speed: 3.3ms preprocess, 13.8ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.4ms
# Speed: 3.6ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.1ms
# Speed: 3.0ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
# 0: 608x800 (no detections), 13.1ms
# Speed: 3.0ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.7ms
# Speed: 3.5ms preprocess, 12.7ms inference, 1.2ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.5ms
# Speed: 4.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.1ms
# Speed: 3.2ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.2ms
# Speed: 3.5ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.1ms
# Speed: 2.9ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.7ms
# Speed: 4.6ms preprocess, 12.7ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.6ms
# Speed: 2.5ms preprocess, 12.6ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.6ms
# Speed: 4.1ms preprocess, 13.6ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 11.6ms
# Speed: 3.5ms preprocess, 11.6ms inference, 1.3ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.6ms preprocess, 12.5ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.7ms
# Speed: 4.0ms preprocess, 12.7ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.0ms
# Speed: 3.2ms preprocess, 12.0ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.2ms
# Speed: 3.5ms preprocess, 12.2ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.8ms
# Speed: 3.6ms preprocess, 12.8ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.9ms
# Speed: 3.0ms preprocess, 13.9ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.6ms
# Speed: 3.5ms preprocess, 12.6ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 3.1ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 3.1ms preprocess, 13.0ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.7ms
# Speed: 3.9ms preprocess, 12.7ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.9ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 4.3ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.8ms
# Speed: 3.7ms preprocess, 12.8ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.3ms
# Speed: 3.9ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.1ms
# Speed: 3.0ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.3ms
# Speed: 3.5ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.7ms
# Speed: 3.0ms preprocess, 12.7ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.2ms
# Speed: 5.5ms preprocess, 12.2ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.2ms
# Speed: 3.1ms preprocess, 13.2ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.3ms
# Speed: 3.6ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.1ms
# Speed: 3.0ms preprocess, 13.1ms inference, 1.3ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.8ms
# Speed: 2.6ms preprocess, 13.8ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 4.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.1ms
# Speed: 3.0ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.3ms
# Speed: 3.0ms preprocess, 12.3ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.6ms
# Speed: 3.5ms preprocess, 12.6ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.7ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 4.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.6ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.7ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.2ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 1.7ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.4ms
# Speed: 3.0ms preprocess, 13.4ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.2ms
# Speed: 3.5ms preprocess, 12.2ms inference, 1.7ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.8ms
# Speed: 3.6ms preprocess, 13.8ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.2ms
# Speed: 3.0ms preprocess, 13.2ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.1ms
# Speed: 4.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
# 0: 608x800 (no detections), 13.3ms
# Speed: 3.0ms preprocess, 13.3ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.1ms
# Speed: 3.0ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 4.1ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.2ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 4.0ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.1ms
# Speed: 3.0ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.8ms
# Speed: 4.5ms preprocess, 12.8ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.1ms
# Speed: 4.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.0ms
# Speed: 4.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 3.3ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.0ms
# Speed: 4.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.5ms
# Speed: 3.2ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.3ms
# Speed: 3.0ms preprocess, 13.3ms inference, 0.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 4.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 3.1ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.6ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.9ms
# Speed: 3.0ms preprocess, 12.9ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.7ms
# Speed: 3.0ms preprocess, 13.7ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.6ms
# Speed: 3.0ms preprocess, 12.6ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.5ms
# Speed: 3.5ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 4.4ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.6ms
# Speed: 3.1ms preprocess, 12.6ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 4.1ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 3.1ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.0ms
# Speed: 4.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 3.2ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.1ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.1ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 4.0ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.0ms
# Speed: 4.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.1ms
# Speed: 3.0ms preprocess, 13.1ms inference, 0.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 3.5ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.1ms
# Speed: 3.0ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 4.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 14.1ms
# Speed: 4.5ms preprocess, 14.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.4ms
# Speed: 3.4ms preprocess, 12.4ms inference, 1.2ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.7ms
# Speed: 4.0ms preprocess, 12.7ms inference, 1.3ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.5ms
# Speed: 3.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.1ms
# Speed: 3.6ms preprocess, 12.1ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 1.2ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.3ms
# Speed: 2.6ms preprocess, 12.3ms inference, 1.2ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.3ms
# Speed: 3.0ms preprocess, 13.3ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.1ms
# ...
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.1ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.1ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.8ms
# Speed: 3.1ms preprocess, 12.8ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.6ms
# Speed: 3.4ms preprocess, 12.6ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 4.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.6ms
# Speed: 3.0ms preprocess, 13.6ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.3ms
# Speed: 3.0ms preprocess, 13.3ms inference, 0.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.1ms
# Speed: 3.0ms preprocess, 13.1ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.7ms
# Speed: 3.0ms preprocess, 12.7ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.1ms
# Speed: 4.0ms preprocess, 12.1ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 11.9ms
# Speed: 3.8ms preprocess, 11.9ms inference, 1.2ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 4.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 3.2ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.8ms
# Speed: 2.8ms preprocess, 13.8ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.9ms
# Speed: 3.7ms preprocess, 12.9ms inference, 0.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.3ms
# Speed: 3.0ms preprocess, 13.3ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.1ms
# Speed: 4.1ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 4.2ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.6ms
# Speed: 3.5ms preprocess, 12.6ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.1ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.9ms
# Speed: 3.2ms preprocess, 12.9ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.1ms
# Speed: 3.0ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.8ms
# Speed: 3.7ms preprocess, 12.8ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.6ms
# Speed: 4.2ms preprocess, 12.6ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.1ms
# Speed: 3.8ms preprocess, 13.1ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.3ms
# Speed: 2.5ms preprocess, 13.3ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.1ms
# Speed: 3.7ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.0ms
# Speed: 3.3ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 4.2ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.6ms
# Speed: 3.0ms preprocess, 13.6ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 3.1ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 4.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.3ms
# Speed: 2.6ms preprocess, 13.3ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.8ms
# Speed: 4.3ms preprocess, 12.8ms inference, 1.2ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.8ms
# Speed: 5.0ms preprocess, 12.8ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.4ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.3ms
# Speed: 3.7ms preprocess, 12.3ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.1ms
# Speed: 3.0ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
# 0: 608x800 (no detections), 13.2ms
# Speed: 3.4ms preprocess, 13.2ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 4.4ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 3.5ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 14.0ms
# Speed: 3.1ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.1ms
# Speed: 3.0ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.4ms
# Speed: 3.5ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.9ms
# Speed: 3.5ms preprocess, 12.9ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.2ms
# Speed: 3.5ms preprocess, 13.2ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.1ms
# Speed: 4.0ms preprocess, 12.1ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.5ms
# Speed: 2.6ms preprocess, 13.5ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.5ms
# Speed: 2.6ms preprocess, 13.5ms inference, 0.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.3ms
# Speed: 3.0ms preprocess, 12.3ms inference, 2.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 3.2ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.9ms
# Speed: 3.7ms preprocess, 12.9ms inference, 1.4ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.3ms
# Speed: 3.6ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.4ms
# Speed: 3.0ms preprocess, 13.4ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 4.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.3ms
# Speed: 2.8ms preprocess, 13.3ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.1ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.5ms
# Speed: 3.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.5ms
# Speed: 4.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.5ms
# Speed: 3.5ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 4.0ms preprocess, 13.0ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.6ms
# Speed: 4.2ms preprocess, 12.6ms inference, 0.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.7ms
# Speed: 4.5ms preprocess, 12.7ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.1ms
# Speed: 3.0ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.2ms
# Speed: 3.8ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 1 fire - v1 2024-01-12 8-02pm, 12.9ms
# Speed: 3.3ms preprocess, 12.9ms inference, 2.3ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 1 fire - v1 2024-01-12 8-02pm, 13.5ms
# Speed: 2.7ms preprocess, 13.5ms inference, 2.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 1 fire - v1 2024-01-12 8-02pm, 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 2.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.3ms
# Speed: 3.1ms preprocess, 12.3ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.6ms
# Speed: 3.0ms preprocess, 12.6ms inference, 1.2ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.9ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 3.5ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 4.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.1ms
# Speed: 3.0ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.1ms
# Speed: 3.5ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.5ms
# Speed: 2.9ms preprocess, 13.5ms inference, 1.3ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.1ms
# Speed: 4.5ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.1ms
# Speed: 4.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.3ms
# Speed: 3.0ms preprocess, 13.3ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 15.8ms
# Speed: 5.0ms preprocess, 15.8ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.7ms
# Speed: 4.5ms preprocess, 12.7ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 3.6ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.9ms
# Speed: 4.0ms preprocess, 12.9ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.3ms
# Speed: 3.0ms preprocess, 12.3ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.1ms
# Speed: 4.1ms preprocess, 12.1ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.1ms
# Speed: 3.5ms preprocess, 12.1ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 14.0ms
# Speed: 2.6ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 4.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.2ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 3.2ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.5ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.4ms
# Speed: 3.6ms preprocess, 12.4ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
# 0: 608x800 (no detections), 12.9ms
# Speed: 3.1ms preprocess, 12.9ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.5ms
# Speed: 3.1ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.4ms
# Speed: 3.5ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.1ms
# Speed: 3.5ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 4.6ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.0ms
# Speed: 3.5ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.5ms
# Speed: 3.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 13.5ms
# Speed: 3.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)
#
# 0: 608x800 (no detections), 12.6ms
# Speed: 3.1ms preprocess, 12.6ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 800)

# %% [markdown]
# ## validating the model on val dataset

# %%
# !yolo task=detect mode=val model=/content/datasets/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml

# %%
# !yolo task=detect mode=val model=../models/best.pt data=../dataset/data2.yaml
# Out:
# Ultralytics YOLOv8.0.196  Python-3.10.0 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
#
# val: Scanning C:\Users\Jarvis\Desktop\Web\Fire_Detection\dataset\valid\labels...:   0%|          | 0/938 [00:00<?, ?it/s]
# val: Scanning C:\Users\Jarvis\Desktop\Web\Fire_Detection\dataset\valid\labels... 79 images, 0 backgrounds, 0 corrupt:   8%|8         | 79/938 [00:00<00:01, 773.80it/s]
# val: Scanning C:\Users\Jarvis\Desktop\Web\Fire_Detection\dataset\valid\labels... 186 images, 0 backgrounds, 0 corrupt:  20%|#9        | 186/938 [00:00<00:00, 944.29it/s]
# val: Scanning C:\Users\Jarvis\Desktop\Web\Fire_Detection\dataset\valid\labels... 286 images, 0 backgrounds, 0 corrupt:  30%|###       | 286/938 [00:00<00:00, 964.74it/s]
# val: Scanning C:\Users\Jarvis\Desktop\Web\Fire_Detection\dataset\valid\labels... 383 images, 0 backgrounds, 0 corrupt:  41%|####      | 383/938 [00:00<00:00, 960.68it/s]
# val: Scanning C:\Users\Jarvis\Desktop\Web\Fire_Detection\dataset\valid\labels... 483 images, 0 backgrounds, 0 corrupt:  51%|#####1    | 483/938 [00:00<00:00, 970.03it/s]
# val: Scanning C:\Users\Jarvis\Desktop\Web\Fire_Detection\dataset\valid\labels... 585 images, 0 backgrounds, 0 corrupt:  62%|######2   | 585/938 [00:00<00:00, 977.00it/s]
# val: Scanning C:\Users\Jarvis\Desktop\Web\Fire_Detection\dataset\valid\labels... 687 images, 0 backgrounds, 0 corrupt:  73%|#######3  | 687/938 [00:00<00:00, 990.22it/s]
# val: Scanning C:\Users\Jarvis\Desktop\Web\Fire_Detection\dataset\valid\labels... 794 images, 0 backgrounds, 0 corrupt:  85%|########4 | 794/938 [00:00<00:00, 1009.81it/s]
# val: Scanning C:\Users\Jarvis\Desktop\Web\Fire_Detection\dataset\valid\labels... 902 images, 0 backgrounds, 0 corrupt:  96%|#########6| 902/938 [00:00<00:00, 1030.60it/s]
# val: Scanning C:\Users\Jarvis\Desktop\Web\Fire_Detection\dataset\valid\labels... 938 images, 0 backgrounds, 0 corrupt: 100%|##########| 938/938 [00:00<00:00, 992.79it/s]
# val: New cache created: C:\Users\Jarvis\Desktop\Web\Fire_Detection\dataset\valid\labels.cache
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/59 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   2%|1         | 1/59 [00:00<00:39,  1.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   3%|3         | 2/59 [00:01<00:34,  1.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   5%|5         | 3/59 [00:01<00:37,  1.48it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   7%|6         | 4/59 [00:02<00:33,  1.62it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   8%|8         | 5/59 [00:02<00:28,  1.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  10%|#         | 6/59 [00:03<00:24,  2.13it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  12%|#1        | 7/59 [00:03<00:22,  2.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  14%|#3        | 8/59 [00:03<00:20,  2.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  15%|#5        | 9/59 [00:04<00:19,  2.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  17%|#6        | 10/59 [00:04<00:18,  2.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  19%|#8        | 11/59 [00:05<00:18,  2.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  20%|##        | 12/59 [00:05<00:17,  2.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  22%|##2       | 13/59 [00:05<00:17,  2.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  24%|##3       | 14/59 [00:06<00:16,  2.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  25%|##5       | 15/59 [00:06<00:16,  2.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  27%|##7       | 16/59 [00:06<00:15,  2.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  29%|##8       | 17/59 [00:07<00:15,  2.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  31%|###       | 18/59 [00:07<00:14,  2.80it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  32%|###2      | 19/59 [00:07<00:14,  2.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  34%|###3      | 20/59 [00:08<00:13,  2.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  36%|###5      | 21/59 [00:08<00:13,  2.83it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  37%|###7      | 22/59 [00:08<00:13,  2.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  39%|###8      | 23/59 [00:09<00:12,  2.83it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  41%|####      | 24/59 [00:09<00:12,  2.85it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  42%|####2     | 25/59 [00:10<00:11,  2.85it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  44%|####4     | 26/59 [00:10<00:11,  2.85it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  46%|####5     | 27/59 [00:10<00:11,  2.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  47%|####7     | 28/59 [00:11<00:11,  2.80it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  49%|####9     | 29/59 [00:11<00:10,  2.79it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  51%|#####     | 30/59 [00:11<00:10,  2.80it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  53%|#####2    | 31/59 [00:12<00:10,  2.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  54%|#####4    | 32/59 [00:12<00:09,  2.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  56%|#####5    | 33/59 [00:12<00:09,  2.71it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  58%|#####7    | 34/59 [00:13<00:09,  2.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  59%|#####9    | 35/59 [00:13<00:08,  2.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  61%|######1   | 36/59 [00:14<00:08,  2.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  63%|######2   | 37/59 [00:14<00:08,  2.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  64%|######4   | 38/59 [00:14<00:07,  2.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  66%|######6   | 39/59 [00:15<00:07,  2.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  68%|######7   | 40/59 [00:15<00:06,  2.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  69%|######9   | 41/59 [00:15<00:06,  2.79it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  71%|#######1  | 42/59 [00:16<00:06,  2.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  73%|#######2  | 43/59 [00:16<00:05,  2.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  75%|#######4  | 44/59 [00:16<00:05,  2.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  76%|#######6  | 45/59 [00:17<00:05,  2.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  78%|#######7  | 46/59 [00:17<00:04,  2.79it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  80%|#######9  | 47/59 [00:18<00:04,  2.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  81%|########1 | 48/59 [00:18<00:03,  2.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  83%|########3 | 49/59 [00:18<00:03,  2.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  85%|########4 | 50/59 [00:19<00:03,  2.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  86%|########6 | 51/59 [00:19<00:02,  2.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  88%|########8 | 52/59 [00:19<00:02,  2.80it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  90%|########9 | 53/59 [00:20<00:02,  2.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  92%|#########1| 54/59 [00:20<00:01,  2.80it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  93%|#########3| 55/59 [00:20<00:01,  2.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  95%|#########4| 56/59 [00:21<00:01,  2.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  97%|#########6| 57/59 [00:21<00:00,  2.80it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  98%|#########8| 58/59 [00:21<00:00,  2.80it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|##########| 59/59 [00:22<00:00,  3.14it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|##########| 59/59 [00:22<00:00,  2.66it/s]
#                    all        938       1753      0.798      0.734      0.778      0.516
#                      -        938         95       0.82      0.821      0.874      0.644
# fire - v1 2024-01-12 8-02pm        938       1658      0.776      0.647      0.682      0.388
# Speed: 1.0ms preprocess, 15.4ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to runs\detect\val
#  Learn more at https://docs.ultralytics.com/modes/val
